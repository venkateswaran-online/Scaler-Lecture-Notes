# %% [markdown]
# <a href="https://colab.research.google.com/github/venkateswaran-online/Scaler-Lecture-Notes/blob/main/AR_DAV5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# #Duplicate analysis

# %%
# Example DataFrame
data = {
    "Restaurant": ["R1", "R2", "R3", "R2", "R4", "R1"],
    "Votes": [120, 240, 150, 240, 80, 120],
    "Rating": [4.1, 4.5, 3.9, 4.5, 4.0, 4.1]
}

sample_df = pd.DataFrame(data)
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R2    240     4.5
# 4         R4     80     4.0
# 5         R1    120     4.1

# %%
sample_df.duplicated(keep="first")
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sample_df.duplicated(keep="last")
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
sample_df[sample_df.duplicated(keep="last")]
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5

# %%
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R2    240     4.5
# 4         R4     80     4.0
# 5         R1    120     4.1

# %%
sample_df.drop_duplicates(keep="first")
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 4         R4     80     4.0

# %%
sample_df.drop_duplicates(keep="last")
# Out:
#   Restaurant  Votes  Rating
# 2         R3    150     3.9
# 3         R2    240     4.5
# 4         R4     80     4.0
# 5         R1    120     4.1

# %%
sample_df.drop_duplicates(keep=False)
# Out:
#   Restaurant  Votes  Rating
# 2         R3    150     3.9
# 4         R4     80     4.0

# %%
sample_df.drop_duplicates(keep=False,inplace=True)
#sample_df = sample_df.drop_duplicates(keep=False)

# %%
sample_df
# Out:
#   Restaurant  Votes  Rating
# 2         R3    150     3.9
# 4         R4     80     4.0

# %%
# Example DataFrame
data = {
    "Restaurant": ["R1", "R2", "R3", "R2", "R4", "R1"],
    "Votes": [120, 240, 150, 240, 80, 120],
    "Rating": [4.1, 4.5, 3.9, 4.5, 4.0, 4.2]
}

sample_df = pd.DataFrame(data)
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R2    240     4.5
# 4         R4     80     4.0
# 5         R1    120     4.2

# %%
sample_df.drop_duplicates(subset=['Restaurant'],keep="last")
# Out:
#   Restaurant  Votes  Rating
# 2         R3    150     3.9
# 3         R2    240     4.5
# 4         R4     80     4.0
# 5         R1    120     4.2

# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/100/375/original/zomato_dataset.zip
# !unzip zomato_dataset.zip
# !mv zomato_dataset.csv .
# Out:
# --2025-05-26 16:03:39--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/100/375/original/zomato_dataset.zip
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 108.157.172.10, 108.157.172.173, 108.157.172.176, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|108.157.172.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72602133 (69M) [application/zip]
# Saving to: ‘zomato_dataset.zip’
#
# zomato_dataset.zip  100%[===================>]  69.24M   221MB/s    in 0.3s
#
# 2025-05-26 16:03:39 (221 MB/s) - ‘zomato_dataset.zip’ saved [72602133/72602133]
#
# Archive:  zomato_dataset.zip
#   inflating: zomato_dataset.csv
# mv: 'zomato_dataset.csv' and './zomato_dataset.csv' are the same file

# %%
df = pd.read_csv('zomato_dataset.csv')

# Let's look at the first few rows to understand the structure
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df['votes'].sum()
# Out:
# np.int64(13940720)

# %%
df["votes"].count()
# Out:
# np.int64(23193)

# %%
df.shape
# Out:
# (23193, 17)

# %%
df["votes"].count().sum()
# Out:
# np.int64(23193)

# %%
df["votes"].agg(['sum','count'])
# Out:
# sum      13940720
# count       23193
# Name: votes, dtype: int64

# %%
df.sort_values("votes")
# Out:
#                                                      url  \
# 6154   https://www.zomato.com/bangalore/46-ounces-bre...
# 6168   https://www.zomato.com/bangalore/shandys-the-b...
# 8155   https://www.zomato.com/bangalore/nevermind-bar...
# 22259  https://www.zomato.com/bangalore/foodbell-sarj...
# 4983   https://www.zomato.com/bangalore/bobs-bar-kora...
# ...                                                  ...
# 1993   https://www.zomato.com/bangalore/byg-brewski-b...
# 1634   https://www.zomato.com/bangalore/byg-brewski-b...
# 22531  https://www.zomato.com/bangalore/byg-brewski-b...
# 22364  https://www.zomato.com/bangalore/byg-brewski-b...
# 22232  https://www.zomato.com/bangalore/byg-brewski-b...
#
#                                                  address  \
# 6154             43, Phase 1, Electronic City, Bangalore
# 6168   3rd Floor, Ajmera Annex, Neeladri Road, Electr...
# 8155   614-615, 12th Main Road, HAL 2nd Stage, Indira...
# ...

# %%
df.sort_values("votes",ascending=False)
# Out:
#                                                      url  \
# 22531  https://www.zomato.com/bangalore/byg-brewski-b...
# 22232  https://www.zomato.com/bangalore/byg-brewski-b...
# 22364  https://www.zomato.com/bangalore/byg-brewski-b...
# 1634   https://www.zomato.com/bangalore/byg-brewski-b...
# 1993   https://www.zomato.com/bangalore/byg-brewski-b...
# ...                                                  ...
# 4632   https://www.zomato.com/bangalore/biergarten-ko...
# 4631   https://www.zomato.com/bangalore/levitate-brew...
# 13722  https://www.zomato.com/bangalore/the-flying-tr...
# 23089  https://www.zomato.com/bangalore/temptation-wh...
# 4644   https://www.zomato.com/bangalore/ulavacharu-ko...
#
#                                                  address  \
# 22531         Behind MK Retail, Sarjapur Road, Bangalore
# 22232         Behind MK Retail, Sarjapur Road, Bangalore
# 22364         Behind MK Retail, Sarjapur Road, Bangalore
# ...

# %%
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R2    240     4.5
# 4         R4     80     4.0
# 5         R1    120     4.2

# %%
# Example DataFrame
data = {
    "Restaurant": ["R1", "R2", "R3", "R2", "R4", "R1"],
    "Votes": [120, 240, 150, 240, 80, 120],
    "Rating": [4.1, 4.5, 3.9, 4.6, 4.0, 4.2]
}

sample_df = pd.DataFrame(data)
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R2    240     4.6
# 4         R4     80     4.0
# 5         R1    120     4.2

# %%
sample_df.sort_values(by=["Votes","Rating"] ,
                      ascending=[False,False])
# Out:
#   Restaurant  Votes  Rating
# 3         R2    240     4.6
# 1         R2    240     4.5
# 2         R3    150     3.9
# 5         R1    120     4.2
# 0         R1    120     4.1
# 4         R4     80     4.0

# %%
sample_df.sort_values(by=["Votes", "Rating"], ascending=[False, True])
#votes - descending order
# Out:
#   Restaurant  Votes  Rating
# 1         R2    240     4.5
# 3         R2    240     4.5
# 2         R3    150     3.9
# 0         R1    120     4.1
# 5         R1    120     4.2
# 4         R4     80     4.0

# %%
sample_df.sort_values(by="Restaurant" ,
                      )
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 5         R1    120     4.2
# 1         R2    240     4.5
# 3         R2    240     4.6
# 2         R3    150     3.9
# 4         R4     80     4.0

# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/214/original/amazon_data4.zip
# Out:
# --2025-05-26 16:24:50--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/214/original/amazon_data4.zip
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 108.157.172.183, 108.157.172.176, 108.157.172.173, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|108.157.172.183|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1943535 (1.9M) [application/zip]
# Saving to: ‘amazon_data4.zip’
#
# amazon_data4.zip    100%[===================>]   1.85M  1.53MB/s    in 1.2s
#
# 2025-05-26 16:24:52 (1.53 MB/s) - ‘amazon_data4.zip’ saved [1943535/1943535]

# %%
# !unzip amazon_data4.zip
# Out:
# Archive:  amazon_data4.zip
#   inflating: products.csv
#   inflating: orders.csv

# %%
import pandas as pd

orders = pd.read_csv('orders.csv')
orders.head()
# Out:
#    product_id                                            user_id  \
# 0  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  B096MSW6CT  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  B08HDJ86NZ  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  B08CF3B7N1  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# ...

# %%
products = pd.read_csv('products.csv')
products.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                 category discounted_price actual_price  rating  rating_count  \
# 0  Computers&Accessories             ₹399       ₹1,099     4.2       24269.0
# 1  Computers&Accessories             ₹199         ₹349     4.0       43994.0
# 2  Computers&Accessories             ₹199       ₹1,899     3.9        7928.0
# 3  Computers&Accessories             ₹329         ₹699     4.2       94363.0
# 4  Computers&Accessories             ₹154         ₹399     4.2       16905.0
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# ...

# %%
import pandas as pd

# Sample DataFrames
samples_orders = pd.DataFrame({
    'product_id': ['P001', 'P002', 'P003'],
    'user_id': ['U001', 'U002', 'U003'],
    'review_id': ['R001', 'R002', 'R003']
})

samples_products = pd.DataFrame({
    'product_id': ['P001', 'P002', 'P004'],
    'product_name': ['Product A', 'Product B', 'Product D'],
    'category': ['Category 1', 'Category 2', 'Category 3']
})

# %%
samples_orders
# Out:
#   product_id user_id review_id
# 0       P001    U001      R001
# 1       P002    U002      R002
# 2       P003    U003      R003

# %%
samples_products
# Out:
#   product_id product_name    category
# 0       P001    Product A  Category 1
# 1       P002    Product B  Category 2
# 2       P004    Product D  Category 3

# %%
inner_join = pd.merge(samples_orders, samples_products, on='product_id', how='inner')#common
inner_join
# Out:
#   product_id user_id review_id product_name    category
# 0       P001    U001      R001    Product A  Category 1
# 1       P002    U002      R002    Product B  Category 2

# %%
#left
#right
#outer

pd.merge(samples_orders, samples_products, on='product_id', how='left')
# Out:
#   product_id user_id review_id product_name    category
# 0       P001    U001      R001    Product A  Category 1
# 1       P002    U002      R002    Product B  Category 2
# 2       P003    U003      R003          NaN         NaN

# %%
samples_orders.columns
# Out:
# Index(['product_id', 'user_id', 'review_id'], dtype='object')

# %%
samples_products.columns
# Out:
# Index(['product_id', 'product_name', 'category'], dtype='object')

# %%
pd.merge(samples_orders, samples_products, on = ['product_id','user_id'], how = 'inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-d8396bc250b5> in <cell line: 0>()
# ----> 1 pd.merge(samples_orders, samples_products, on = ['product_id','user_id'], how = 'inner')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#
# ...

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left: 'DataFrame | Series', right: 'DataFrame | Series', how: 'MergeHow' = 'inner', on: 'IndexLabel | AnyArrayLike | None' = None, left_on: 'IndexLabel | AnyArrayLike | None' = None, right_on: 'IndexLabel | AnyArrayLike | None' = None, left_index: 'bool' = False, right_index: 'bool' = False, sort: 'bool' = False, suffixes: 'Suffixes' = ('_x', '_y'), copy: 'bool | None' = None, indicator: 'str | bool' = False, validate: 'str | None' = None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     A named Series object is treated as a DataFrame with a single named column.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
# ...

# %%
df = pd.merge(orders, products, on='product_id', how='left')

# Displaying the result
print("Best Join (Left Join) for Our Use Case:")
df.head()
# Out:
# Best Join (Left Join) for Our Use Case:
#    product_id                                            user_id  \
# 0  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 2  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 3  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 4  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 2  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 3  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 4  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# ...

# %%
df['review_title'].head()
# Out:
# 0    Satisfied,Charging is really fast,Value for mo...
# 1    Satisfied,Charging is really fast,Value for mo...
# 2    Satisfied,Charging is really fast,Value for mo...
# 3    A Good Braided Cable for Your Type C Device,Go...
# 4    A Good Braided Cable for Your Type C Device,Go...
# Name: review_title, dtype: object

# %%
#upper
def uppercase_title(value):
   return value.upper()

# %%
uppercase_title("santosh")
# Out:
# 'SANTOSH'

# %%
df['review_title'].apply(uppercase_title)
# Out:
# 0       SATISFIED,CHARGING IS REALLY FAST,VALUE FOR MO...
# 1       SATISFIED,CHARGING IS REALLY FAST,VALUE FOR MO...
# 2       SATISFIED,CHARGING IS REALLY FAST,VALUE FOR MO...
# 3       A GOOD BRAIDED CABLE FOR YOUR TYPE C DEVICE,GO...
# 4       A GOOD BRAIDED CABLE FOR YOUR TYPE C DEVICE,GO...
#                               ...
# 1732    RECEIVED THE PRODUCT WITHOUT SPANNER,EXCELLENT...
# 1733    OK,EVERYTHING WAS GOOD COULDN'T RETURN BCOZ I ...
# 1734    VERY GOOD,WORK BUT FRONT MELT AFTER 2 MONTH,GO...
# 1735    FAN SPEED IS SLOW,GOOD QUALITY,GOOD PRODUCT,GO...
# 1736    WORKS PERFECT,OK GOOD PRODUCT,NICE PRODUCT. RE...
# Name: review_title, Length: 1737, dtype: object

# %%
df['review_title_uppercase'] = df['review_title'].apply(uppercase_title)

# %%
df.head()
# Out:
#    product_id                                            user_id  \
# 0  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 2  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 3  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 4  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 2  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 3  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 4  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# ...

# %%
df['review_title'].apply(lambda values:values.upper())
# Out:
# 0       SATISFIED,CHARGING IS REALLY FAST,VALUE FOR MO...
# 1       SATISFIED,CHARGING IS REALLY FAST,VALUE FOR MO...
# 2       SATISFIED,CHARGING IS REALLY FAST,VALUE FOR MO...
# 3       A GOOD BRAIDED CABLE FOR YOUR TYPE C DEVICE,GO...
# 4       A GOOD BRAIDED CABLE FOR YOUR TYPE C DEVICE,GO...
#                               ...
# 1732    RECEIVED THE PRODUCT WITHOUT SPANNER,EXCELLENT...
# 1733    OK,EVERYTHING WAS GOOD COULDN'T RETURN BCOZ I ...
# 1734    VERY GOOD,WORK BUT FRONT MELT AFTER 2 MONTH,GO...
# 1735    FAN SPEED IS SLOW,GOOD QUALITY,GOOD PRODUCT,GO...
# 1736    WORKS PERFECT,OK GOOD PRODUCT,NICE PRODUCT. RE...
# Name: review_title, Length: 1737, dtype: object

# %%
print(df['discounted_price'].head())
print(df['actual_price'].head())
# Out:
# 0    ₹399
# 1    ₹399
# 2    ₹399
# 3    ₹199
# 4    ₹199
# Name: discounted_price, dtype: object
# 0    ₹1,099
# 1    ₹1,099
# 2    ₹1,099
# 3      ₹349
# 4      ₹349
# Name: actual_price, dtype: object

# %%
"₹399".replace("₹","").replace(",","")
# Out:
# '399'

# %%
def extract_price(price_str):
    return float(str(price_str).replace('₹', '').replace(',', ''))

# %%
df['actual_price'] = df['actual_price'].apply(extract_price)
df['actual_price']
# Out:
# 0       1099.0
# 1       1099.0
# 2       1099.0
# 3        349.0
# 4        349.0
#          ...
# 1732     919.0
# 1733    3045.0
# 1734    3080.0
# 1735    1890.0
# 1736    3690.0
# Name: actual_price, Length: 1737, dtype: float64

# %%
df['discounted_price'] = df['discounted_price'].apply(extract_price)
df['discounted_price']
# Out:
# 0        399.0
# 1        399.0
# 2        399.0
# 3        199.0
# 4        199.0
#          ...
# 1732     379.0
# 1733    2280.0
# 1734    2219.0
# 1735    1399.0
# 1736    2863.0
# Name: discounted_price, Length: 1737, dtype: float64

# %%
((1099-399)/1099)*100
# Out:
# 63.69426751592356

# %%
df.head()
# Out:
#    product_id                                            user_id  \
# 0  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 2  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 3  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 4  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 2  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 3  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 4  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# ...

# %%
def calculate_discount_percentage(row):
    return ((row['actual_price'] - row['discounted_price']) / row['actual_price']) * 100

# %%
df['calculated_discount'] = df.apply(calculate_discount_percentage, axis = 1)

# %% [markdown]
# # Null Values

# %%
df.head(2)
# Out:
#    product_id                                            user_id  \
# 0  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  Satisfied,Charging is really fast,Value for mo...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  Looks durable Charging is fine tooNo complains...
#
#                  order_timestamp  \
# 0  2023-01-01 00:00:00.000000000
# 1  2023-01-01 00:00:00.000000000
#
# ...

# %%
df.isnull()
# Out:
#       product_id  user_id  user_name  review_id  review_title  review_content  \
# 0          False    False      False      False         False           False
# 1          False    False      False      False         False           False
# 2          False    False      False      False         False           False
# 3          False    False      False      False         False           False
# 4          False    False      False      False         False           False
# ...          ...      ...        ...        ...           ...             ...
# 1732       False    False      False      False         False           False
# 1733       False    False      False      False         False           False
# 1734       False    False      False      False         False           False
# 1735       False    False      False      False         False           False
# 1736       False    False      False      False         False           False
#
# ...

# %%
True+True+False
#1+1+0
# Out:
# 2

# %%
df.isnull().sum()
# Out:
# product_id                 0
# user_id                    0
# user_name                  0
# review_id                  0
# review_title               0
# review_content             0
# order_timestamp            0
# product_name               0
# category                  13
# discounted_price          13
# actual_price               8
# rating                    20
# rating_count               2
# about_product              0
# img_link                   0
# product_link               0
# review_title_uppercase     0
# calculated_discount       21
# dtype: int64

# %%
df['discounted_price'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1732    False
# 1733    False
# 1734    False
# 1735    False
# 1736    False
# Name: discounted_price, Length: 1737, dtype: bool

# %%
df[~df['discounted_price'].isnull()]
# Out:
#       product_id                                            user_id  \
# 0     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 2     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 3     B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 4     B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# ...          ...                                                ...
# 1732  B08L7J3T31  AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# 1733  B01M6453MB  AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# 1734  B009P2LIL4  AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZ...
# 1735  B00J5DYCCA  AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# 1736  B01486F4G6  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
#                                               user_name  \
# 0     Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# ...

# %%
df['discounted_price'].mean()
# Out:
# np.float64(2765.136432714617)

# %%
df['discounted_price'].fillna(df['discounted_price'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# product_id                 0
# user_id                    0
# user_name                  0
# review_id                  0
# review_title               0
# review_content             0
# order_timestamp            0
# product_name               0
# category                  13
# discounted_price           0
# actual_price               8
# rating                    20
# rating_count               2
# about_product              0
# img_link                   0
# product_link               0
# review_title_uppercase     0
# calculated_discount       21
# dtype: int64

# %% [markdown]
# # groupby

# %%
df.groupby('category')['calculated_discount'].mean()
# Out:
# category
# Car&Motorbike            41.525000
# Computers&Accessories    55.374270
# Electronics              52.152439
# Health&PersonalCare      52.684211
# Home&Kitchen             40.241448
# HomeImprovement          57.944088
# MusicalInstruments       45.808298
# OfficeProducts           12.771811
# Toys&Games                0.000000
# Name: calculated_discount, dtype: float64

# %%
df.groupby('category')['calculated_discount'].count()
# Out:
# category
# Car&Motorbike              1
# Computers&Accessories    641
# Electronics              586
# Health&PersonalCare        1
# Home&Kitchen             439
# HomeImprovement            2
# MusicalInstruments         2
# OfficeProducts            30
# Toys&Games                 1
# Name: calculated_discount, dtype: int64

# %%
df[df['category'] == "Car&Motorbike"]
# Out:
#       product_id                                            user_id  \
# 1429  B0912WJ87V  AG6W5HESRSDLBX3NCYOOUGFOWERA,AED4U5CF37HVSYPMD...
#
#                                               user_name  \
# 1429  Arivazhagan,Ajit,swanand pandit,Venkatesh S.,S...
#
#                                               review_id  \
# 1429  R3TOOFPX256D59,R1PR50BDQOEIIO,R392FI4QWXWOX5,R...
#
#                                            review_title  \
# 1429  Liked it,User friendly and effective,Not as pe...
#
#                                          review_content  \
# 1429  As of now its working fine, but don't expect m...
#
#                     order_timestamp  \
# 1429  2023-10-15 16:03:56.065573772
#
#                                            product_name       category  \
# 1429  Reffair AX30 [MAX] Portable Air Purifier for C...  Car&Motorbike
#
#       discounted_price  actual_price  rating  rating_count  \
# 1429            2339.0        4000.0     3.8        1118.0
#
# ...

# %%
rating_stats = df.groupby(['category', 'product_name'])['rating_count'].agg(['max', 'min'])

rating_stats
# Out:
#                                                                               max  \
# category              product_name
# Car&Motorbike         Reffair AX30 [MAX] Portable Air Purifier for Ca...   1118.0
# Computers&Accessories APC Back-UPS BX600C-IN 600VA / 360W, 230V, UPS ...  15783.0
#                       Acer EK220Q 21.5 Inch (54.61 cm) Full HD (1920x...   2014.0
#                       Agaro Blaze USBA to micro +Type C 2in1 Braided ...  14184.0
#                       AirCase Protective Laptop Bag Sleeve fits Upto ...   9940.0
# ...                                                                           ...
# OfficeProducts        Pentonic Multicolor Ball Point Pen, Pack of 10       4308.0
#                       Pilot Frixion Clicker Roller Pen (Blue), (90000...   6199.0
#                       Pilot V7 Liquid Ink Roller Ball Pen (2 Blue + 1...   2450.0
#                       Portronics Ruffpad 15 Re-Writable LCD Screen 38...   3530.0
# ...

# %%
df.groupby('category')['rating'].mean()
# Out:
# category
# Car&Motorbike            3.800000
# Computers&Accessories    4.158934
# Electronics              4.090508
# Health&PersonalCare      4.000000
# Home&Kitchen             4.045890
# HomeImprovement          4.250000
# MusicalInstruments       3.900000
# OfficeProducts           4.309677
# Toys&Games               4.300000
# Name: rating, dtype: float64

# %%
#.loc[R,C]
#.loc[R] #all the column
#R - R>=4 #
#True

# %%
df.groupby('category')['rating'].mean().loc[lambda x:x>=4]
# Out:
# category
# Computers&Accessories    4.158934
# Electronics              4.090508
# Health&PersonalCare      4.000000
# Home&Kitchen             4.045890
# HomeImprovement          4.250000
# OfficeProducts           4.309677
# Toys&Games               4.300000
# Name: rating, dtype: float64

# %%
df.groupby('user_id').filter(
    lambda x : x['review_id'].count() >15
)
# Out:
#      product_id                                            user_id  \
# 3    B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 4    B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 5    B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 25   B082LZGK39  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 26   B082LZGK39  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 44   B082LSVT4B  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 45   B082LSVT4B  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 57   B09NHVCHS9  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# 58   B09NHVCHS9  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# 59   B09NHVCHS9  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# 98   B09NJN8L25  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# 160  B09NKZXMWJ  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# 258  B0B3N8VG24  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# ...

# %%
df["votes"].count() and df["votes"].count().sum() isnt it the same whats the diffrence?

# %%
sample_data["votes"].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-a195484d2495> in <cell line: 0>()
# ----> 1 sample_data["votes"].count()
#
# NameError: name 'sample_data' is not defined

# %%
def my_aggregations(group):
    return pd.Series({
        'mean_rating': group['rating'].mean(),
        'min_discounted_price': group['discounted_price'].min(),
        'max_discounted_price': group['discounted_price'].max()
    })

# %%
result =  df.groupby('category').apply(my_aggregations)
result
# Out:
# <ipython-input-122-e6c9df9497b0>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result =  df.groupby('category').apply(my_aggregations)
#                        mean_rating  min_discounted_price  max_discounted_price
# category
# Car&Motorbike             3.800000                2339.0                2339.0
# Computers&Accessories     4.158934                  39.0               37247.0
# Electronics               4.090508                  79.0               77990.0
# Health&PersonalCare       4.000000                 899.0                 899.0
# Home&Kitchen              4.045890                  79.0               42990.0
# ...

# %%
type(result)
# Out:
# pandas.core.frame.DataFrame

# %%
df.groupby('category').apply(my_aggregations)
#elc
# Out:
# <ipython-input-111-24072df14a55>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('category').apply(my_aggregations)
#                        mean_rating  min_discounted_price  max_discounted_price
# category
# Car&Motorbike             3.800000                2339.0                2339.0
# Computers&Accessories     4.158934                  39.0               37247.0
# Electronics               4.090508                  79.0               77990.0
# Health&PersonalCare       4.000000                 899.0                 899.0
# Home&Kitchen              4.045890                  79.0               42990.0
# ...

# %%
df['about_product']
# Out:
# 0       High Compatibility : Compatible With iPhone 12...
# 1       High Compatibility : Compatible With iPhone 12...
# 2       High Compatibility : Compatible With iPhone 12...
# 3       Compatible with all Type C enabled devices, be...
# 4       Compatible with all Type C enabled devices, be...
#                               ...
# 1732    SUPREME QUALITY 90 GRAM 3 LAYER THIK PP SPUN F...
# 1733                         230 Volts, 400 watts, 1 Year
# 1734    International design and styling|Two heat sett...
# 1735    Fan sweep area: 230 MM ; Noise level: (40 - 45...
# 1736    Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
# Name: about_product, Length: 1737, dtype: object

# %%
df['about_product'].str.contains("Compatibility")
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 1732    False
# 1733    False
# 1734    False
# 1735    False
# 1736    False
# Name: about_product, Length: 1737, dtype: bool

# %%
df['product_link'][0]
# Out:
# 'https://www.amazon.in/Wayona-Braided-WN3LG1-Syncing-Charging/dp/B07JW9H4J1/ref=sr_1_1?qid=1672909124&s=electronics&sr=1-1'

# %%
df['product_link'][0].split('qid=')
# Out:
# ['https://www.amazon.in/Wayona-Braided-WN3LG1-Syncing-Charging/dp/B07JW9H4J1/ref=sr_1_1?',
#  '1672909124&s=electronics&sr=1-1']

# %%
df['product_link'][0].split('qid=')[1]
# Out:
# '1672909124&s=electronics&sr=1-1'

# %%
def extract_qid(link):
    # Split on 'qid=' and take the part after it
    qid_part = link.split('qid=')[-1]
    # Further split by '&' to isolate the QID
    return qid_part.split('&')[0] if 'qid=' in link else None

# Apply the function to extract QID
df['product_qid'] = df['product_link'].apply(extract_qid)

# %%
print(df[['product_link', 'product_qid']].head())
# Out:
#                                         product_link product_qid
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...  1672909124
# 1  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...  1672895755
# 2  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...  1672902996
# 3  https://www.amazon.in/Ambrane-Unbreakable-Char...  1672909124
# 4  https://www.amazon.in/Ambrane-Unbreakable-Char...  1672895755

# %%
sum([30])
# Out:
# 30
